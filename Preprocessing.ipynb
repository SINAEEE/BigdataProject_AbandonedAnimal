# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv("D:\pycharmProject\BigdataProject_AbandonedAnimal\lostAnimal_20180101_20181231_vol2.csv", encoding="euc-kr")
#df2=pd.read_excel("D:\JupyterNotebook\project\lostAnimal_data\processing_data\lostAnimal_20160101_20161231.xlsx", encoding="euc-kr")
#df3=pd.read_excel("D:\JupyterNotebook\project\lostAnimal_data\processing_data\lostAnimal_20170101_20171231.xlsx", encoding="euc-kr")
#df4=pd.read_excel("D:\JupyterNotebook\project\lostAnimal_data\processing_data\lostAnimal_20180101_20181231.xlsx", encoding="euc-kr")

# %%
df1

# %%
#all_df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])
#cs=all_df.drop(['Unnamed: 0','chargeNm','desertionNo','filename','noticeComment','officetel','popfile','specialMark','orgNm'],axis=1)
df1=df1.drop(['두마리이상'],axis=1)
#df2=df2.drop(['Unnamed: 0','chargeNm','desertionNo','filename','noticeComment','officetel','popfile','specialMark','orgNm','careTel'],axis=1)
#df3=df3.drop(['Unnamed: 0','chargeNm','desertionNo','filename','noticeComment','officetel','popfile','specialMark','orgNm','careTel'],axis=1)
#df4=df4.drop(['Unnamed: 0','chargeNm','desertionNo','filename','noticeComment','officetel','popfile','specialMark','orgNm','careTel'],axis=1)

# %%
df1[['processState','sexCd','neuterYn']].isnull().sum()

# %%
#df2[['processState','sexCd','neuterYn']].isnull().sum()

# %%
#df3[['processState','sexCd','neuterYn']].isnull().sum()

# %%
#df4[['processState','sexCd','neuterYn']].isnull().sum()

# %%
df1['processState'].value_counts()

# %% [markdown]
# ### (processState, sexCd, neuterYn) 전처리(레이블링, column화, one-hot 코딩)

# %%
df1.loc[df1['processState']=='보호중','processState_Pre'] ='C'# 보호중
df1.loc[df1['processState']=='종료(입양)','processState_Pre']='A'
df1.loc[df1['processState']=='종료(기증)','processState_Pre']='A'
df1.loc[df1['processState']=='종료(자연사)','processState_Pre']='D'
df1.loc[df1['processState']=='종료(안락사)','processState_Pre']='D'
df1.loc[df1['processState']=='종료(반환)','processState_Pre']='R'
df1.loc[df1['processState']=='종료(방사)','processState_Pre']='E'
df1.loc[df1['processState']=='종료(미포획)','processState_Pre']='E'

# %%
# 데이터에서 값제거 코드
#df1 = df1[df1.processState!='종료(방사)']

# %%
df1['processState_C']=df1['processState']=='C' #보호중
df1['processState_A']=df1['processState']=='A' #입양+기증
df1['processState_D']=df1['processState']=='D' #자연사+안락사
df1['processState_R']=df1['processState']=='R' #반환
df1['processState_E']=df1['processState']=='E' #미포획+방사
df1[['processState','processState_C','processState_A','processState_D','processState_R','processState_E']].head(20)
# Out:
#    processState  processState_C  processState_A  processState_D  \
# 0           보호중           False           False           False
# 1           보호중           False           False           False
# 2           보호중           False           False           False
# 3           보호중           False           False           False
# 4           보호중           False           False           False
# 5           보호중           False           False           False
# 6           보호중           False           False           False
# 7           보호중           False           False           False
# 8        종료(입양)           False           False           False
# 9           보호중           False           False           False
# 10          보호중           False           False           False
# 11          보호중           False           False           False
# 12          보호중           False           False           False
# 13          보호중           False           False           False
# 14          보호중           False           False           False
# 15          보호중           False           False           False
# 16          보호중           False           False           False
# 17          보호중           False           False           False
# 18          보호중           False           False           False
# 19          보호중           False           False           False
#
#     processState_R  processState_E
# 0            False           False
# 1            False           False
# 2            False           False
# 3            False           False
# 4            False           False
# 5            False           False
# 6            False           False
# 7            False           False
# 8            False           False
# 9            False           False
# 10           False           False
# 11           False           False
# 12           False           False
# 13           False           False
# 14           False           False
# 15           False           False
# 16           False           False
# 17           False           False
# 18           False           False
# 19           False           False

# %% [markdown]
# ### 성별( M=남, F=여자, Q=미상)

# %%
df1['sexCd_M']=df1['sexCd']=='M'
df1['sexCd_F']=df1['sexCd']=='F'
df1['sexCd_Q']=df1['sexCd']=='Q'
df1[['sexCd','sexCd_M','sexCd_F','sexCd_Q']].head(30)
# Out:
#    sexCd  sexCd_M  sexCd_F  sexCd_Q
# 0      F    False     True    False
# 1      M     True    False    False
# 2      M     True    False    False
# 3      F    False     True    False
# 4      F    False     True    False
# 5      F    False     True    False
# 6      M     True    False    False
# 7      F    False     True    False
# 8      F    False     True    False
# 9      M     True    False    False
# 10     F    False     True    False
# 11     M     True    False    False
# 12     F    False     True    False
# 13     M     True    False    False
# 14     M     True    False    False
# 15     M     True    False    False
# 16     F    False     True    False
# 17     F    False     True    False
# 18     F    False     True    False
# 19     M     True    False    False
# 20     Q    False    False     True
# 21     Q    False    False     True
# 22     M     True    False    False
# 23     M     True    False    False
# 24     Q    False    False     True
# 25     Q    False    False     True
# 26     M     True    False    False
# 27     M     True    False    False
# 28     Q    False    False     True
# 29     M     True    False    False

# %% [markdown]
# ### 중성화여부 (Y=중성화, N=중성화X, U=미확인)

# %%
df1['neuterYn_Y']=df1['neuterYn']=='Y'
df1['neuterYn_N']=df1['neuterYn']=='N'
df1['neuterYn_U']=df1['neuterYn']=='U'
df1[['neuterYn','neuterYn_Y','neuterYn_N','neuterYn_U']].head(20)
# Out:
#    neuterYn  neuterYn_Y  neuterYn_N  neuterYn_U
# 0         N       False        True       False
# 1         N       False        True       False
# 2         N       False        True       False
# 3         N       False        True       False
# 4         N       False        True       False
# 5         N       False        True       False
# 6         N       False        True       False
# 7         U       False       False        True
# 8         N       False        True       False
# 9         N       False        True       False
# 10        U       False       False        True
# 11        N       False        True       False
# 12        N       False        True       False
# 13        N       False        True       False
# 14        N       False        True       False
# 15        N       False        True       False
# 16        N       False        True       False
# 17        U       False       False        True
# 18        N       False        True       False
# 19        Y        True       False       False

# %% [markdown]
# ### 보호장소

# %%
dfh1=df1['careNm'].str.contains('병원|의료센터|메디컬|클리닉|의료원') #메디컬(715)+의료(91)+의료(23408)
dfh2=df1['careNm'].str.contains('보호소|보호센터|리본센터') #보호소(18387)+센터(18413)
dfh3=df1['careNm'].str.contains('군청|시청') #군청(54)+시청(24)
dfh4=df1['careNm'].str.contains('수의사회') #수의사회(2443)
dfh5=df1['careNm'].str.contains('한동보|협회|보호협' ) #한동보(1115)+동물협회(10806)
dfh6=df1['careNm'].str.contains('병원|의료|메디컬|클리닉|보호소|보호센터|리본센터|군청|시청|수의사회|한동보|협회|보호협|의료원')==False

# %%
df1['careNm_ETC']=dfh6 #밑에 컬럼속성들을 제외한 속성
df1['careNm_H']=dfh1 # 병원,의료센터,메디컬,클리닉,의료원
df1['careNm_C']=dfh2 # 보호소,보호센터,리본센터
df1['careNm_O']=dfh3 # 군청, 시청
df1['careNm_AD']=dfh4 # 수의사회
df1['careNm_CM']=dfh5 # 한동보,동물협회

# %%
df1[['careNm','careNm_ETC','careNm_H','careNm_C','careNm_O','careNm_AD','careNm_CM']]
# Out:
#             careNm  careNm_ETC  careNm_H  careNm_C  careNm_O  careNm_AD  \
# 0           포두동물병원       False      True     False     False      False
# 1           포두동물병원       False      True     False     False      False
# 2           포두동물병원       False      True     False     False      False
# 3           포두동물병원       False      True     False     False      False
# 4           포두동물병원       False      True     False     False      False
# 5           포두동물병원       False      True     False     False      False
# 6           포두동물병원       False      True     False     False      False
# 7         당진시동물보호소       False     False      True     False      False
# 8         반려동물보호센터       False     False      True     False      False
# 9         반려동물보호센터       False     False      True     False      False
# 10        반려동물보호센터       False     False      True     False      False
# 11        반려동물보호센터       False     False      True     False      False
# 12        강아지와 고양이        True     False     False     False      False
# 13        강아지와 고양이        True     False     False     False      False
# 14        강아지와 고양이        True     False     False     False      False
# 15        강아지와 고양이        True     False     False     False      False
# 16        강아지와 고양이        True     False     False     False      False
# 17         오산시수의사회       False     False     False     False       True
# 18      24시아이동물메디컬       False      True     False     False      False
# 19      24시아이동물메디컬       False      True     False     False      False
# 20           허동물병원       False      True     False     False      False
# 21          예스동물병원       False      True     False     False      False
# 22     대구시수의사회(보경)       False     False     False     False       True
# 23     대구시수의사회(보경)       False     False     False     False       True
# 24      유기동물및동물보호협       False     False     False     False      False
# 25      유기동물및동물보호협       False     False     False     False      False
# 26          누리동물병원       False      True     False     False      False
# 27      유기동물및동물보호협       False     False     False     False      False
# 28      유기동물및동물보호협       False     False     False     False      False
# 29      유기동물및동물보호협       False     False     False     False      False
# ...            ...         ...       ...       ...       ...        ...
# 80300    남양주동물보호협회       False     False     False     False      False
# 80301    남양주동물보호협회       False     False     False     False      False
# 80302       (사)한동보       False     False     False     False      False
# 80303       (사)한동보       False     False     False     False      False
# 80304       (사)한동보       False     False     False     False      False
# 80305       (사)한동보       False     False     False     False      False
# 80306       (사)한동보       False     False     False     False      False
# 80307       (사)한동보       False     False     False     False      False
# 80308   평택시유기동물보호소       False     False      True     False      False
# 80309   평택시유기동물보호소       False     False      True     False      False
# 80310   평택시유기동물보호소       False     False      True     False      False
# 80311   평택시유기동물보호소       False     False      True     False      False
# 80312   평택시유기동물보호소       False     False      True     False      False
# 80313   평택시유기동물보호소       False     False      True     False      False
# 80314   평택시유기동물보호소       False     False      True     False      False
# 80315   한국야생동물보호협회       False     False     False     False      False
# 80316   한국야생동물보호협회       False     False     False     False      False
# 80317   한국야생동물보호협회       False     False     False     False      False
# 80318   한국야생동물보호협회       False     False     False     False      False
# 80319   24시아이동물메디컬       False      True     False     False      False
# 80320   24시아이동물메디컬       False      True     False     False      False
# 80321   24시아이동물메디컬       False      True     False     False      False
# 80322   24시아이동물메디컬       False      True     False     False      False
# 80323   한국야생동물보호협회       False     False     False     False      False
# 80324     펫토피아동물병원       False      True     False     False      False
# 80325      광교산동물병원       False      True     False     False      False
# 80326     광주 동물보호소       False     False      True     False      False
# 80327     광주 동물보호소       False     False      True     False      False
# 80328     광주 동물보호소       False     False      True     False      False
# 80329      제니스동물병원       False      True     False     False      False
#
#        careNm_CM
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24          True
# 25          True
# 26         False
# 27          True
# 28          True
# 29          True
# ...          ...
# 80300       True
# 80301       True
# 80302       True
# 80303       True
# 80304       True
# 80305       True
# 80306       True
# 80307       True
# 80308      False
# 80309      False
# 80310      False
# 80311      False
# 80312      False
# 80313      False
# 80314      False
# 80315       True
# 80316       True
# 80317       True
# 80318       True
# 80319      False
# 80320      False
# 80321      False
# 80322      False
# 80323       True
# 80324      False
# 80325      False
# 80326      False
# 80327      False
# 80328      False
# 80329      False
#
# [80330 rows x 7 columns]

# %%
df1.to_csv('test_df1-1.csv',encoding='euc-kr')

# %%
# df1['orgNm'][df1['orgNm'].str.contains('서울특별시')==True]
# df1['orgNm'][df1['orgNm'].str.contains('경기도')==True]
# df1['orgNm'][df1['orgNm'].str.contains('강원도')==True]
# df1['orgNm'][df1['orgNm'].str.contains('경상남도')==True]
# df1['orgNm'][df1['orgNm'].str.contains('경상북도')==True]
# df1['orgNm'][df1['orgNm'].str.contains('전라남도')==True]
# df1['orgNm'][df1['orgNm'].str.contains('전라북도')==True]
# df1['orgNm'][df1['orgNm'].str.contains('충청남도')==True]
# df1['orgNm'][df1['orgNm'].str.contains('충청북도')==True]
# df1['orgNm'][df1['orgNm'].str.contains('울산광역시')==True]
# df1['orgNm'][df1['orgNm'].str.contains('부산광역시')==True]
# df1['orgNm'][df1['orgNm'].str.contains('대전광역시')==True]
# df1['orgNm'][df1['orgNm'].str.contains('제주특별자치도')==True]
#df1['orgNm'].unique()

# %%
df1['orgNm'].str.contains('서울특별시').sum()

# %%
df1['orgNm'].str.contains('경기도').sum()

# %%
df1['orgNm'].str.contains('강원도').sum()

# %%
df1['orgNm'].str.contains('경상남도').sum()

# %%
df1['orgNm'].str.contains('경상북도').sum()

# %%
df1['orgNm'].str.contains('전라남도').sum()

# %%
df1['orgNm'].str.contains('전라북도').sum()

# %%
df1['orgNm'].str.contains('충청남도').sum()

# %%
df1['orgNm'].str.contains('충청북도').sum()

# %%
df1['orgNm'].str.contains('울산광역시').sum()

# %%
df1['orgNm'].str.contains('부산광역시').sum()

# %%
df1['orgNm'].str.contains('대전광역시').sum()

# %%
df1['orgNm'].str.contains('제주특별자치도').sum()

# %%
df1['orgNm'].str.contains('세종특별자치시').sum()

# %%
df1['orgNm'].str.contains('인천광역시').sum()

# %%
df1['orgNm'].str.contains('광주광역시').sum()

# %%
df1['orgNm'].str.contains('대구광역시').sum()

# %% [markdown]
# ### KindCd, happenDt, happenPlace, colorCd

# %% [markdown]
# ### Kind Cd

# %%
df1['kindCd'].head()

# %%
df1['kind'] = df1['kindCd'].str.extract('([가-힣]+)\]', expand=False) # 한글 정규식
df1['kind'].head()

# %%
kind_mapping = {'개': 0, '고양이':1, '기타축종':2}
df1['kind'] = df1['kind'].map(kind_mapping)

# %%
df1['kind'].value_counts()

# %%
df1['breed'] = df1['kindCd'].str.split('] ').str[1]

# %%
df1['breed'].head()

# %%
# breed = df1['breed'].value_counts()
# breed

# %% [markdown]
# ### happenDt

# %%
df1['happenDt']

# %%
df1['happenDt'] = pd.to_datetime(df1['happenDt'], format='%Y%m%d')
# 8자리를 날짜형식으로 바꿈

# %%
df1['happenDt'].head()

# %%
# df['happenWd'] = df['happenDt'].dt.dayofweekday  # 요일을 숫자로 표현함 "0 = Sunday"
df1['happenWd'] = df1['happenDt'].dt.day_name()

# %%
df1['happenWd'].head()

# %%
df1['happenWd'].value_counts()

# %%
df1['happenMth'] = pd.DatetimeIndex(df1['happenDt']).month
# 날짜에서 '월'값을 받음

# %%
df1['happenMth'].value_counts()

# %% [markdown]
# ### weight

# %%
df1['weight(after)'].head()

# %%
df1.loc[df1['weight(after)'] <= 3, 'size'] = '초소형'
df1.loc[(df1['weight(after)'] > 3 ) & (df1['weight(after)'] <=9 ), 'size'] = '소형'
df1.loc[(df1['weight(after)'] > 9 ) & (df1['weight(after)'] <=25 ), 'size'] = '중형'
df1.loc[df1['weight(after)'] > 25, 'size'] = '대형'

# %%
df1['size'].head()

# %%
df1.loc[df1['age(after)'] <= 1, 'age_u'] = '유견기'
df1.loc[(df1['age(after)'] > 1 ) & (df1['age(after)'] <= 9 ), 'age_u'] = '성견기'
df1.loc[df1['age(after)'] > 9, 'age_u'] = '노견기'

# %%
df1['age_u'].head()

# %%
df1.columns

# %%
df1.to_csv('lostAnimal_20180101_20181231_vol3.csv',encoding='euc-kr')
